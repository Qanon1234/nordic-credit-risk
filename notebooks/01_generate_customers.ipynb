# %%
import pandas as pd
import numpy as np

np.random.seed(42)

# %%
# skapa först 100 kunder
number_of_customers = 10000

#skapa tom lista för att spara kund:id
customer_ids = []

# gå igenom kundnummer 1 till 100
for customer_number in range(1, number_of_customers + 1):

 # skapa ett kundID, exempelvis C00001
 customer_id = f"C{customer_number:05d}"
 # lägg in IDt i listan
 customer_ids.append(customer_id)

print(customer_ids)
# Out:
# ['C00001', 'C00002', 'C00003', 'C00004', 'C00005', 'C00006', 'C00007', 'C00008', 'C00009', 'C00010', 'C00011', 'C00012', 'C00013', 'C00014', 'C00015', 'C00016', 'C00017', 'C00018', 'C00019', 'C00020', 'C00021', 'C00022', 'C00023', 'C00024', 'C00025', 'C00026', 'C00027', 'C00028', 'C00029', 'C00030', 'C00031', 'C00032', 'C00033', 'C00034', 'C00035', 'C00036', 'C00037', 'C00038', 'C00039', 'C00040', 'C00041', 'C00042', 'C00043', 'C00044', 'C00045', 'C00046', 'C00047', 'C00048', 'C00049', 'C00050', 'C00051', 'C00052', 'C00053', 'C00054', 'C00055', 'C00056', 'C00057', 'C00058', 'C00059', 'C00060', 'C00061', 'C00062', 'C00063', 'C00064', 'C00065', 'C00066', 'C00067', 'C00068', 'C00069', 'C00070', 'C00071', 'C00072', 'C00073', 'C00074', 'C00075', 'C00076', 'C00077', 'C00078', 'C00079', 'C00080', 'C00081', 'C00082', 'C00083', 'C00084', 'C00085', 'C00086', 'C00087', 'C00088', 'C00089', 'C00090', 'C00091', 'C00092', 'C00093', 'C00094', 'C00095', 'C00096', 'C00097', 'C00098', 'C00099', 'C00100
# ...

# %%
# Svenska åldersgrupper med befolkningsstorlek som vikt
age_groups = [
    (20, 24, 602823),
    (25, 34, 1363717),
    (35, 44, 1423815),
    (45, 54, 1306445),
    (55, 64, 1293429),
    (65, 79, 1551575)
]

# Hämta befolkningsstorleken från varje grupp
age_weights = []

for group in age_groups:
    age_weights.append(group[2])

# Gör om befolkningsstorlekarna till sannolikheter
age_probabilities = np.array(age_weights) / sum(age_weights)

# Välj först vilken åldersgrupp varje kund ska tillhöra
selected_age_groups = np.random.choice(
    len(age_groups),
    number_of_customers,
    p=age_probabilities
)

# Skapa sedan den exakta åldern
ages = []

for group_number in selected_age_groups:

    minimum_age = age_groups[group_number][0]
    maximum_age = age_groups[group_number][1]

    age = np.random.randint(minimum_age, maximum_age + 1)

    ages.append(age)

print(ages[:10])
# Out:
# [41, 68, 56, 49, 27, 33, 20, 67, 48, 63]

# %%
regions = [
    "Stockholms län",
    "Uppsala län",
    "Södermanlands län",
    "Östergötlands län",
    "Jönköpings län",
    "Kronobergs län",
    "Kalmar län",
    "Gotlands län",
    "Blekinge län",
    "Skåne län",
    "Hallands län",
    "Västra Götalands län",
    "Värmlands län",
    "Örebro län",
    "Västmanlands län",
    "Dalarnas län",
    "Gävleborgs län",
    "Västernorrlands län",
    "Jämtlands län",
    "Västerbottens län",
    "Norrbottens län"
]

region_populations = np.array([
    2486251,
    410575,
    300440,
    472529,
    369722,
    203121,
    245477,
    60852,
    156616,
    1433083,
    346090,
    1777803,
    283037,
    308357,
    280756,
    286043,
    283452,
    240640,
    132736,
    279028,
    248927
])

region_probabilities = region_populations / region_populations.sum()

customer_regions = np.random.choice(
    regions,
    number_of_customers,
    p=region_probabilities
)

print(customer_regions[:10])
# Out:
# ['Stockholms län' 'Stockholms län' 'Dalarnas län' 'Västra Götalands län'
#  'Östergötlands län' 'Skåne län' 'Stockholms län' 'Västra Götalands län'
#  'Stockholms län' 'Västra Götalands län']

# %%
employment_statuses = [
    "Permanent employment",
    "Self-employed",
    "Temporary/Probation/Freelance",
    "Parental leave",
    "Student",
    "Unemployed",
    "Retired"
]

customer_employment_status = []

for age in ages:

    # Yngre kunder
    if age <= 24:

        probabilities = [
            0.30,  # Permanent employment
            0.03,  # Self-employed
            0.17,  # Temporary/Probation/Freelance
            0.01,  # Parental leave
            0.42,  # Student
            0.07,  # Unemployed
            0.00   # Retired
        ]

    # 25-34 år
    elif age <= 34:

        probabilities = [
            0.64,
            0.07,
            0.10,
            0.07,
            0.05,
            0.07,
            0.00
        ]

    # 35-54 år
    elif age <= 54:

        probabilities = [
            0.73,
            0.10,
            0.05,
            0.04,
            0.01,
            0.07,
            0.00
        ]

    # 55-62 år
    elif age <= 62:

        probabilities = [
            0.65,
            0.10,
            0.05,
            0.00,
            0.02,
            0.10,
            0.08
        ]

    # 63-66 år
    elif age <= 66:

        probabilities = [
            0.42,
            0.08,
            0.03,
            0.00,
            0.01,
            0.06,
            0.40
        ]

    # 67 år och äldre
    else:

        probabilities = [
            0.08,
            0.03,
            0.01,
            0.00,
            0.00,
            0.01,
            0.87
        ]

    employment_status = np.random.choice(
        employment_statuses,
        p=probabilities
    )

    customer_employment_status.append(employment_status)

print(customer_employment_status[:10])
# Out:
# [np.str_('Temporary/Probation/Freelance'), np.str_('Retired'), np.str_('Permanent employment'), np.str_('Permanent employment'), np.str_('Permanent employment'), np.str_('Self-employed'), np.str_('Self-employed'), np.str_('Retired'), np.str_('Permanent employment'), np.str_('Permanent employment')]

# %%
customer_monthly_income = []

for age, employment_status in zip(ages, customer_employment_status):

    if employment_status == "Permanent employment":

        if age <= 24:
            average_income = 30000
        elif age <= 34:
            average_income = 38000
        elif age <= 54:
            average_income = 45000
        else:
            average_income = 43000

        income = np.random.normal(average_income, 7000)
        income = np.clip(income, 22000, 90000)

    elif employment_status == "Self-employed":

        income = np.random.normal(45000, 18000)
        income = np.clip(income, 18000, 150000)

    elif employment_status == "Temporary/Probation/Freelance":

        income = np.random.normal(30000, 8000)
        income = np.clip(income, 15000, 60000)

    elif employment_status == "Parental leave":

        income = np.random.normal(30000, 6000)
        income = np.clip(income, 16000, 50000)

    elif employment_status == "Student":

        income = np.random.normal(10000, 5000)
        income = np.clip(income, 0, 25000)

    elif employment_status == "Unemployed":

        income = np.random.normal(14000, 4000)
        income = np.clip(income, 0, 25000)

    else:  # Retired

        income = np.random.normal(23900, 7000)
        income = np.clip(income, 12000, 60000)

    income = round(income / 100) * 100

    customer_monthly_income.append(int(income))

print(customer_monthly_income[:10])
# Out:
# [26400, 18900, 30800, 35700, 45900, 29900, 57100, 24000, 42600, 40000]

# %%
customers_df = pd.DataFrame({
    "customer_id": customer_ids,
    "age": ages,
    "region": customer_regions,
    "monthly_income": customer_monthly_income,
    "employment_status": customer_employment_status
})

customers_df.head(10)
# Out:
#   customer_id  age                region  monthly_income  \
# 0      C00001   41        Stockholms län           26400
# 1      C00002   68        Stockholms län           18900
# 2      C00003   56          Dalarnas län           30800
# 3      C00004   49  Västra Götalands län           35700
# 4      C00005   27     Östergötlands län           45900
# 5      C00006   33             Skåne län           29900
# 6      C00007   20        Stockholms län           57100
# 7      C00008   67  Västra Götalands län           24000
# 8      C00009   48        Stockholms län           42600
# 9      C00010   63  Västra Götalands län           40000
#
#                employment_status
# 0  Temporary/Probation/Freelance
# 1                        Retired
# 2           Permanent employment
# 3           Permanent employment
# 4           Permanent employment
# 5                  Self-employed
# 6                  Self-employed
# 7                        Retired
# ...

# %%
print("Antal kunder:", len(customers_df))

print("\nSaknade värden:")
print(customers_df.isna().sum())

print("\nSysselsättningsfördelning:")
print(customers_df["employment_status"].value_counts())

print("\nÅlder:")
print("Min:", customers_df["age"].min())
print("Max:", customers_df["age"].max())

print("\nInkomst:")
print("Min:", customers_df["monthly_income"].min())
print("Max:", customers_df["monthly_income"].max())
print("Medel:", round(customers_df["monthly_income"].mean()))
# Out:
# Antal kunder: 10000
#
# Saknade värden:
# customer_id          0
# age                  0
# region               0
# monthly_income       0
# employment_status    0
# dtype: int64
#
# Sysselsättningsfördelning:
# employment_status
# Permanent employment             5397
# Retired                          1827
# Self-employed                     759
# Temporary/Probation/Freelance     618
# Unemployed                        601
# Student                           525
# Parental leave                    273
# Name: count, dtype: int64
#
# Ålder:
# Min: 20
# Max: 79
#
# Inkomst:
# Min: 0
# Max: 97500
# Medel: 34744

# %%
print("Unika kund-ID:", customers_df["customer_id"].nunique())
print("Duplicerade kund-ID:", customers_df["customer_id"].duplicated().sum())
# Out:
# Unika kund-ID: 10000
# Duplicerade kund-ID: 0

# %%
customers_df.groupby("employment_status")["monthly_income"].agg(
    ["count", "mean", "min", "max"]
).round(0)
# Out:
#                                count     mean    min    max
# employment_status
# Parental leave                   273  29787.0  16000  44300
# Permanent employment            5397  42351.0  22000  72200
# Retired                         1827  24079.0  12000  45700
# Self-employed                    759  45404.0  18000  97500
# Student                          525  10191.0      0  25000
# Temporary/Probation/Freelance    618  30031.0  15000  54100
# Unemployed                       601  13945.0   3700  25000

# %%
from pathlib import Path

project_root = Path.cwd()

if project_root.name == "notebooks":
    project_root = project_root.parent

output_path = project_root / "data" / "customers.csv"

customers_df.to_csv(
    output_path,
    index=False,
    encoding="utf-8-sig"
)

print("CSV sparad här:")
print(output_path)
# Out:
# CSV sparad här:
# c:\Users\ELIYA\Documents\nordic-credit-risk\data\customers.csv
